# %%
from sklearn.datasets import load_boston
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
data = load_boston()
X = pd.DataFrame(data = data['data'],columns = data['feature_names'])
y = data['target']

# %%
kmn = KMeans(n_clusters = 3, random_state = 42, max_iter = 100)

# %%
kmn_X = kmn.fit_predict(X)

# %%
tsne = TSNE(n_components = 2, learning_rate = 250, random_state = 42)
X_tsne = tsne.fit_transform(X)

# %%
plt.scatter(X_tsne[:, 0], X_tsne[:, 1], c = kmn_X)

# %%
X['CRIM'
# Out:
# False

# %%
k_1, k_2, k_3 = kmn_X == 0, kmn_X == 1, kmn_X == 2

# %%
print(f' Средняя цена для кластеров 1 : {np.mean(y[k_1])}, 2: {np.mean(y[k_2])}, 3: {np.mean(y[k_3])}')
# Out:
#  Средняя цена для кластеров 1 : 17.42941176470588, 2: 24.93169398907104, 3: 13.126315789473683

# %%
print(f' Средняя показатель CRIM для кластеров 1 :{np.mean(X[k_1]["CRIM"])}, 2 : {np.mean(X[k_2]["CRIM"])}, 3 : {np.mean(X[k_3]["CRIM"])}')
# Out:
#  Средняя показатель CRIM для кластеров 1 :10.910511274509803, 2 : 0.3749926775956283, 3 : 15.219038157894733
